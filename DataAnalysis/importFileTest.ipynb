# %%
# %cd ..
# Out:
# /Users/edwardgunn/Documents/4YP/DistributedReinforcementLearningOnTheEdge

# %%
import pickle
  
f = open('ExperimentFramework/Experiments/Results/2.pkl', 'rb')

data = pickle.load(f)
for episode, steps in data["algorithms"]["DQL"][1]["Blackjack-v1"].items():
    if episode != "parameters":
        print(episode, steps)

f.close()
# Out:
# 0 {1: {'centralLearner': {'message': defaultdict(<bound method DQLearner.zerosReturn of <ExperimentFramework.CentralLearners.DQLearner.DQLearner object at 0x105a5e590>>, {(10, 2, False): array([0., 0.]), None: array([-0.9,  0. ])}), 'valueFunction': defaultdict(<bound method DQLearner.zerosReturn of <ExperimentFramework.CentralLearners.DQLearner.DQLearner object at 0x105a5e590>>, {(10, 2, False): array([0., 0.]), None: array([-0.9,  0. ])})}, UUID('c9b174ec-ec57-41cf-8217-c4027e680b70'): {'lastState': None, 'lastAction': 0, 'reward': -1.0, 'currentState': 0, '?message': None}}}
# ...
